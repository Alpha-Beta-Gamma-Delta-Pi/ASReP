# %%
import json

# Read the text file
with open('Beauty_reversed200Beauty_result.txt', 'r') as file:
    text_data = file.read()

# Convert the text data to JSON format
json_data = json.dumps(text_data)

# Convert the JSON data to a Python dictionary
data = json.loads(json_data)

data = "  " + data.strip()

# print((data))

# %%
# print((data))

# %%
# s,e = 0,0
# data = "  " + data.strip()
# all_data={}
# i,j = 0,0

# %%
# if (e<len(data)):
#     e = data.index(':',s+1)
#     s += 2
#     dt = (data[s:e])
#     print(dt,s,e)
#     if (dt[:3] == "200"):
#         print("-------")
#         i = dt[4:]
#         all_data[i] = {}
#         print(dt[4:])
#     elif (dt[0] == '{'):
#         print(",,,,,")
#         print(dt[1:])
#         j = dt[2:-1]
#         print(j)
#         all_data[i][j] = ""
#     elif (dt[:5] == "array"):
#         print(".....")
#         e = dt.index(']')
#         dt = dt[7:e] #.strip()
#         print([float(i) for i in dt.split(",")])
#         all_data[i][j] = [float(i) for i in dt.split(",")]
#         e += 2
#         # s=e
#         e += s
#         print(data[s:e],s,e)
#         # s += e
#     elif "mrr" in dt:
#         print("*****")
#         print(dt[:dt.index(',')])
#         all_data[i][j] = float(dt[:dt.index(',')])
#         e += 2
#         j = "mrr"
#         all_data[i][j] = ""
#         print("mrr")
#     elif dt == "epoch":
#         print("!!!!!!!!!!!!")
#         # continue
#     elif "\n\nepoch" in dt:
#         val = "0." + dt[:-8]
#         print(float(val))
#         all_data[i][j] = float(val)
#     else:
#         print("#########")
#         j = dt[1:-1]
#         print(j)
#         all_data[i][j] = ""

#     s = e
#     print("@@@@@@@@@@@@@@@@@@@@@")
#     print(all_data)

# %%
# s,e = 0,0
# all_data = {}
# i,j = '',0

# %%
# if (e<len(data)):
#     e = data.index(':',s+1) if ':' in data[s+1:] else len(data)
#     s += 2
#     dt = (data[s:e])
#     # print(dt,s,e)
#     if (dt[:3] == "200"):
#         # print("-------")
#         i = dt[4:]
#         all_data[i] = {}
#         # print(dt[4:])
#     # elif (e==-1):
#     #     print("-------")
#     elif (dt[0] == '{'):
#         # print(",,,,,")
#         # print(dt[1:])
#         j = dt[2:-1]
#         # print(j)
#         all_data[i][j] = ""
#     elif (dt[:5] == "array"):
#         # print(".....")
#         e = dt.index(']')
#         dt = dt[7:e] #.strip()
#         # print([float(i) for i in dt.split(",")])
#         all_data[i][j] = [float(i) for i in dt.split(",")]
#         e += 2
#         # s=e
#         e += s
#         # print(data[s:e],s,e)
#         # s += e
#     elif "mrr" in dt:
#         # print("*****")
#         # print(dt[:dt.index(',')])
#         all_data[i][j] = float(dt[:dt.index(',')])
#         e += 2
#         j = "mrr"
#         all_data[i][j] = ""
#         # print("mrr")
#     elif dt == "epoch":
#         print("!!!!!!!!!!!!")
#         # continue
#     elif e == len(data):   #"\n\nepoch" in dt:
#         val = "0." + dt[:-1]
#         # print(float(val))
#         all_data[i][j] = float(val)
#     elif "\n\nepoch" in dt:
#         val = "0." + dt[:-8]
#         print(float(val))
#         all_data[i][j] = float(val)
#     else:
#         # print("#########")
#         j = dt[1:-1]
#         # print(j)
#         all_data[i][j] = 0

#     s = e
#     print("@@@@@@@@@@@@@@@@@@@@@")
#     print(all_data)
# # return all_data

# %%
# def proper_form(data):
#     s,e = 0,0
#     all_data = {}
#     i,j = '',0
#     while (e<len(data)):
#         e = data.index(':',s+1)  if ':' in data[s+1:] else len(data)
#         s += 2
#         dt = (data[s:e])
#         # print(dt,s,e)
#         if (dt[:3] == "200"):
#             # print("-------")
#             i = dt[4:]
#             all_data[i] = {}
#             # print(dt[4:])
#         elif (dt[0] == '{'):
#             # print(",,,,,")
#             # print(dt[1:])
#             j = dt[2:-1]
#             # print(j)
#             all_data[i][j] = ""
#         elif (dt[:5] == "array"):
#             # print(".....")
#             e = dt.index(']')
#             dt = dt[7:e] #.strip()
#             # print([float(i) for i in dt.split(",")])
#             all_data[i][j] = [float(i) for i in dt.split(",")]
#             e += 2
#             # s=e
#             e += s
#             # print(data[s:e],s,e)
#             # s += e
#         elif "mrr" in dt:
#             # print("*****")
#             # print(dt[:dt.index(',')])
#             all_data[i][j] = float(dt[:dt.index(',')])
#             e += 2
#             j = "mrr"
#             all_data[i][j] = 0
#             # print("mrr")
#         elif dt == "epoch":
#             # print("!!!!!!!!!!!!")
#             continue
#         elif e == len(data):   #"\n\nepoch" in dt:
#             val = "0." + dt[:-1]
#             # print(float(val))
#             all_data[i][j] = float(val)
#         elif "\n\nepoch" in dt:
#             val = "0." + dt[:-8]
#             # print(float(val))
#             all_data[i][j] = float(val)
#         elif e == len(data):   #"\n\nepoch" in dt:
#             val = "0." + dt
#             # print(float(val))
#             all_data[i][j] = float(val)
#         else:
#             # print("#########")
#             j = dt[1:-1]
#             all_data[i][j] = 0

#         s = e
#         # print("@@@@@@@@@@@@@@@@@@@@@")
#         print(all_data)
#     return all_data

# %%
def proper_form(data):
    s,e = 0,0
    all_data = {}
    i,j = '',0

    while (e<len(data)):
        e = data.index(':',s+1) if ':' in data[s+1:] else len(data)
        s += 2
        dt = (data[s:e])
        # print(dt,s,e)
        if (dt[:3] == "200"):
            # print("-------")
            i = dt[4:]
            all_data[i] = {}
            # print(dt[4:])
        # elif (e==-1):
        #     print("-------")
        elif (dt[0] == '{'):
            # print(",,,,,")
            # print(dt[1:])
            j = dt[2:-1]
            # print(j)
            all_data[i][j] = ""
        elif (dt[:5] == "array"):
            # print(".....")
            e = dt.index(']')
            dt = dt[7:e] #.strip()
            # print([float(i) for i in dt.split(",")])
            all_data[i][j] = [float(i) for i in dt.split(",")]
            e += 2
            # s=e
            e += s
            # print(data[s:e],s,e)
            # s += e
        elif "mrr" in dt:
            # print("*****")
            # print(dt[:dt.index(',')])
            all_data[i][j] = float(dt[:dt.index(',')])
            e += 2
            j = "mrr"
            all_data[i][j] = ""
            # print("mrr")
        elif dt == "epoch":
            print("!!!!!!!!!!!!")
            # continue
        elif e == len(data):   #"\n\nepoch" in dt:
            val = "0." + dt[:-1]
            # print(float(val))
            all_data[i][j] = float(val)
        elif "\nepoch" in dt:
            val = "0." + dt[:dt.index('}')]
            # print(float(val))
            all_data[i][j] = float(val)
        else:
            # print("#########")
            j = dt[1:-1]
            # print(j)
            all_data[i][j] = 0

        s = e
        # print("@@@@@@@@@@@@@@@@@@@@@")
        # print(all_data)
    return all_data

# %%
original_results = proper_form(data)
# Out:
# !!!!!!!!!!!!

# %%
import json

# Read the text file
with open('Beauty2_reversed200Beauty2_result.txt', 'r') as file:
    text_data = file.read()

# Convert the text data to JSON format
json_data = json.dumps(text_data)

# Convert the JSON data to a Python dictionary
data2 = json.loads(json_data)

data2 = "  " + data2.strip()

# print((data2))

# %%
modified_results = proper_form(data2)
# Out:
# !!!!!!!!!!!!

# %%
# import matplotlib.pyplot as plt

# # Extract the data from the dictionaries
# original_precision = original_results['validationall']['precision']
# original_recall = original_results['validationall']['recall']
# modified_precision = modified_results['validationall']['precision']
# modified_recall = modified_results['validationall']['recall']

# # Plot the precision and recall curves
# plt.plot(original_precision, label='Original Precision')
# plt.plot(original_recall, label='Original Recall')
# plt.plot(modified_precision, label='Modified Precision')
# plt.plot(modified_recall, label='Modified Recall')

# # Add labels and title
# plt.xlabel('Rank')
# plt.ylabel('Value')
# plt.title('Precision and Recall Curves')
# plt.legend()

# # Show the plot
# plt.show()

# %%
print(modified_results)
print(original_results)
# Out:
# {'validationall': {'precision': [0.25832042, 0.18763108, 0.14794383, 0.12234431, 0.10465943, 0.06299809, 0.03662579, 0.02085005, 0.01731741, 0.01493952, 0.01318436, 0.01184747, 0.01079704, 0.00995259], 'recall': [0.25832042, 0.37526215, 0.44383149, 0.48937722, 0.52329716, 0.62998085, 0.73251573, 0.83400201, 0.86587034, 0.89637093, 0.92290508, 0.94779794, 0.97173338, 0.9952585], 'ndcg': [0.25832042, 0.33210244, 0.36638711, 0.38600259, 0.39912461, 0.43361767, 0.45959723, 0.4803923, 0.486158, 0.49140695, 0.49579061, 0.49977079, 0.50349003, 0.50705574], 'hit_ratio': [0.25832042, 0.37526215, 0.44383149, 0.48937722, 0.52329716, 0.62998085, 0.73251573, 0.83400201, 0.86587034, 0.89637093, 0.92290508, 0.94779794, 0.97173338, 0.9952585], 'auc': 0.8310043767666316, 'mrr': 0.38537816388180696}, 'testall': {'precision': [0.22658886, 0.16606638, 0.13201726, 0.11107185, 0.09565971, 0.05875353, 0.03444424, 0.01991657, 0.01670922, 0.01443573, 0.01279879, 0.01154372, 0.01060099, 0.00989605], 'recall': [0.22658886, 0.33213276, 0.39605179, 0.44428741, 0.47829853, 0.58753533, 0.68888484, 0.79666272, 0.83546093, 0.86614389, 0.89591502, 0.92349777, 0.95408954, 0.98960518], 'ndcg': [0.22658886, 0.29317965, 0.32513916, 0.34591311, 0.35907041, 0.39433248, 0.41994542, 0.44202482, 0.44903841, 0.45431509, 0.45923273, 0.46364154, 0.46839622, 0.47377746], 'hit_ratio': [0.22658886, 0.33213276, 0.39605179, 0.44428741, 0.47829853, 0.58753533, 0.68888484, 0.79666
84892488, 0.88159732, 0.91371125, 0.94722145, 0.9913432], 'ndcg': [0.17634739, 0.2342252, 0.26368624, 0.28419178, 0.29807354, 0.33680004, 0.36744827, 0.3911387, 0.39891367, 0.40549299, 0.41089414, 0.41602645, 0.42123169, 0.42791564], 'hit_ratio': [0.17634739, 0.26808154, 0.32700363, 0.37461603, 0.41049986, 0.53071768, 0.65191287, 0.76766266, 0.81066741, 0.84892488, 0.88159732, 0.91371125, 0.94722145, 0.9913432], 'auc': 0.7731750907567525, 'mrr': 0.2928387720075146}, 'validationshort7': {'precision': [0.19153132, 0.14089327, 0.1136891, 0.09589617, 0.08395592, 0.05280162, 0.03220998, 0.01927059, 0.01632599, 0.01424691, 0.0127113, 0.01154002, 0.0106142, 0.00995186], 'recall': [0.19153132, 0.28178654, 0.34106729, 0.38358469, 0.41977958, 0.52801624, 0.64419954, 0.77082367, 0.8162993, 0.85481439, 0.88979118, 0.92320186, 0.95527842, 0.99518561], 'ndcg': [0.19153132, 0.24847603, 0.2781164, 0.29642765, 0.31042974, 0.34536995, 0.37472695, 0.40063118, 0.40884024, 0.41546494, 0.42124851, 0.42658912, 0.43157421, 0.43762657], 'hit_ratio': [0.19153132, 0.28178654, 0.34106729, 0.38358469, 0.41977958, 0.52801624, 0.64419954, 0.77082367, 0.8162993, 0.85481439, 0.88979118, 0.92320186, 0.95527842, 0.99518561], 'auc': 0.7772737819025116, 'mrr': 0.3047034806079505}, 'testshort7': {'precision': [0.18335267, 0.13808 ...

# %%
cat = modified_results.keys()
print(cat)
vals = original_results['validationall'].keys()
print(vals)
# Out:
# dict_keys(['validationall', 'testall', 'validationshort', 'testshort', 'validationshort7', 'testshort7', 'validationshort37', 'testshort37', 'validationmedium3', 'testmedium3', 'validationmedium7', 'testmedium7', 'validationlong', 'testlong'])
# dict_keys(['precision', 'recall', 'ndcg', 'hit_ratio', 'auc', 'mrr'])

# %%
import matplotlib.pyplot as plt

for i in cat:
    plt.figure(figsize=(15, 12))
    for j in list(vals):
        # plt.figure(figsize=(10, 6))
        if j in ['auc','mrr']:
            o = [original_results[i][j] for _ in range(15)]
            m = [modified_results[i][j] for _ in range(15)]
        else:
            o = original_results[i][j]
            m = modified_results[i][j]
        plt.plot(o, label='Original '+j)
        plt.plot(m, label='Modified '+j)
        
        # Add labels and title
        plt.xlabel('Rank')
        plt.ylabel('Value')
        plt.title(i + ' ' + j +' Curve')
        plt.legend()

        # Show the plot
        # plt.savefig('plots' + i + ' ' + j + '.png')
    
    plt.savefig(i)
    # plt.show()
    # break

# %%
import json

# Specify the file path where you want to save the JSON file
file_path = 'Beauty_reversed_200_Beauty_result.json'

# Open the file in write mode
with open(file_path, 'w') as file:
    # Convert the dictionary to JSON format and write it to the file
    json.dump(original_results, file)


# Specify the file path where you want to save the JSON file
file_path = 'Beauty2_reversed_200_Beauty2_result.json'

# Open the file in write mode
with open(file_path, 'w') as file:
    # Convert the dictionary to JSON format and write it to the file
    json.dump(modified_results, file)
